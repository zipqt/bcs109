# %% [markdown]
# # Investment Strategy
# This worksheet will assist in financial decisions
#
#
#
# 1.   The first section takes an investment goal, investment time, and interest rate and outputs the future value.
# 2.   The second section takes an investment amount, interest rate, and investmnet time and outputs future value
#
#
# *   future value
# *   present value
# *   interest rate
# *   principal

# %%
fv = float(input('what is your target goal? '))
num_years = float(input('How many years will you invest? '))
interest_rate = float(input('What will the investment rate be? '))

present_value = fv / (1 + interest_rate)**num_years
1
print('The present value is ',present_value)

# %%
pv = float(input('what is your starting investment? '))
num_years = float(input('How many years will you invest? '))
interest_rate = float(input('What will the investment rate be? '))

future_val = pv * (1 + interest_rate)**num_years

print('The future value is $',future_val)
