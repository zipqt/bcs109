# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("https://raw.githubusercontent.com/KeithGalli/pandas/master/pokemon_data.csv")

#prints first 5 columns of data
#df.head()

#prints first 5 pokemon names
#df["Name"][0:5]

#prints the Health Points of the first 5 pokemon
#df["HP"][0:5]

#creates a scatter plot that shows the relation between a pokemons HP and Attack
#df.plot.scatter(x="HP", y="Attack", alpha=0.5)

#checks for nulls
#df.isnull().sum()

# %% [markdown]
# Data science is the practice of solving problems using data.
#
# The process of data science includes discovery, data preparation, model planning, model building, operationalizing, and communicating results.
#
#
# The key difference between lists and tuples is that lists can be manipulated and changed while tuples can not.
#
# scikit learn is used for machine learning. It is used to model data as well as predicting unknown values based on previous data.
#
# pandas is used to analyze and manipulate data within python.
#
# tensorflow is another machine learning library similar to Scikit learn.
#
# numpy is used for scientific computing. It can create multi-dimensional array objects.
#
# tkinter is a library that can be used to make GUIs
